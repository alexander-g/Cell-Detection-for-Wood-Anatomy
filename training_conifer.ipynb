# %%
import sys, os
#restrict gpu usage
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import torch, torchvision
print('PyTorch version:          ', torch.__version__)
import pytorch_lightning as pl
print('PyTorch Lightning version:', pl.__version__)

import glob, tempfile
from pylab import *
import dataset, detector, util, evaluation

import PIL
PIL.Image.MAX_IMAGE_PIXELS = None #Needed to open large images

import warnings
warnings.simplefilter("ignore")
# Out:
# PyTorch version:           1.6.0+cu101
# PyTorch Lightning version: 1.0.6

# %% [markdown]
# ***
# **Data collection**

# %%
IMAGEFILES    = sorted(glob.glob('data/conifer/train/*.jpg', recursive=True))
LABELFILES    = sorted(glob.glob('data/conifer/train/*.png', recursive=True))

print(f'Found {len(IMAGEFILES)} images and {len(LABELFILES)} annotations')
assert len(IMAGEFILES) == len(LABELFILES)
# Out:
# Found 31 images and 31 annotations

# %%
#example images
PATCHSIZE = 800
ds = dataset.Dataset(IMAGEFILES, LABELFILES, patchsize=PATCHSIZE, augment=True)

figure(0, (20,8))
for i in range(5):
    j     = np.random.randint(len(ds))
    a0,b0 = ds[j]
    subplot(2,5,i+1);   imshow(a0.transpose(1,2,0)); axis('off'); 
    [util.draw_box(b.numpy(), color='k', linewidth=2) for b in b0['boxes'] ];
    if len(b0['masks']):
        subplot(2,5,i+1+5); imshow(b0['masks'].max(0)[0].numpy()); axis('off');

# %% [markdown]
# ***
# **Training**

# %%
basemodel = detector.create_conifer_basemodel()
trainer   = detector.create_trainer(epochs=20)
loader    = dataset.create_dataloader(ds, shuffle=True, batchsize=1)
trainer.fit(detector.TrainingModel(basemodel), loader)
basemodel.cpu().eval();
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | basemodel | MaskRCNN | 44 M
# [0000] loss:  1.36000 | loss_classifier_step:  0.12720 | loss_box_reg_step:  0.15509 | loss_mask_step:  0.19390 | loss_objectness_step:  0.26240 | loss_rpn_box_reg_step:  0.26041 | loss_classifier_epoch:  1.13565 | loss_box_reg_epoch:  0.36366 | loss_mask_epoch:  0.35459 | loss_objectness_epoch:  1.36928 | loss_rpn_box_reg_epoch:  0.25900
# [0001] loss:  0.88800 | loss_classifier_step:  0.21075 | loss_box_reg_step:  0.28532 | loss_mask_step:  0.29673 | loss_objectness_step:  0.15454 | loss_rpn_box_reg_step:  0.39607 | loss_classifier_epoch:  0.12541 | loss_box_reg_epoch:  0.22061 | loss_mask_epoch:  0.20574 | loss_objectness_epoch:  0.16137 | loss_rpn_box_reg_epoch:  0.19572
# [0002] loss:  0.74700 | loss_classifier_step:  0.12371 | loss_box_reg_step:  0.27966 | loss_mask_step:  0.26096 | loss_objectness_step:  0.04631 | loss_rpn_box_reg_step:  0.08626 | loss_classifier_epoch:  0.09885 | loss_box_reg_epoch:  0.20906 | loss_mask_epoch:  0.19024 | loss_objectness_epoch:  0.12978 | loss_rpn_box_reg_epoch:  0.16696
# [0003] loss:  0.75800 | loss_classifier_step:  0.06932 | loss_box_reg_step:  0.11951 | loss_mask_step:  0.16461 | loss_objectness_step:  0.23045 | loss_rpn_box_reg_step:  0.20571 | loss_classifier_epoch:  0.10209 | loss_box_reg_epoch:  0.18862 | loss_mask_epoch:  0.18806 | loss_objectness_epoch:  0.12000 | loss_rpn_box_reg_epoch:  0.16277
# [0004] loss:  0.72200 | loss_classifier_step:  0.08926 | loss_box_reg_step:  0.10447 | loss_mask_step:  0.11152 | loss_objectness_step:  0.02048 | loss_rpn_box_reg_step:  0.03507 | loss_classifier_epoch:  0.09773 | loss_box_reg_epoch:  0.17768 | loss_mask_epoch:  0.18126 | loss_objectness_epoch:  0.11111 | loss_rpn_box_reg_epoch:  0.15997
# [0005] loss:  0.79500 | loss_classifier_step:  0.07182 | loss_box_reg_step:  0.18876 | loss_mask_step:  0.20284 | loss_objectness_step:  0.12613 | loss_rpn_box_reg_step:  0.23712 | loss_classifier_epoch:  0.09354 | loss_box_reg_epoch:  0.17544 | loss_mask_epoch:  0.18300 | loss_objectness_epoch:  0.10467 | loss_rpn_box_reg_epoch:  0.15993
# [0006] loss:  0.64600 | loss_classifier_step:  0.10555 | loss_box_reg_step:  0.15571 | loss_mask_step:  0.18016 | loss_objectness_step:  0.10460 | loss_rpn_box_reg_step:  0.12333 | loss_classifier_epoch:  0.09387 | loss_box_reg_epoch:  0.16845 | loss_mask_epoch:  0.17467 | loss_objectness_epoch:  0.10524 | loss_rpn_box_reg_epoch:  0.14519
# [0007] loss:  0.72900 | loss_classifier_step:  0.11352 | loss_box_reg_step:  0.18977 | loss_mask_step:  0.13852 | loss_objectness_step:  0.04816 | loss_rpn_box_reg_step:  0.10607 | loss_classifier_epoch:  0.09733 | loss_box_reg_epoch:  0.17618 | loss_mask_epoch:  0.18136 | loss_objectness_epoch:  0.11415 | loss_rpn_box_reg_epoch:  0.16394
# [0008] loss:  0.76100 | loss_classifier_step:  0.04431 | loss_box_reg_step:  0.14233 | loss_mask_step:  0.18919 | loss_objectness_step:  0.13177 | loss_rpn_box_reg_step:  0.14999 | loss_classifier_epoch:  0.09669 | loss_box_reg_epoch:  0.17028 | loss_mask_epoch:  0.18014 | loss_objectness_epoch:  0.10982 | loss_rpn_box_reg_epoch:  0.15417
# [0009] loss:  0.68700 | loss_classifier_step:  0.04214 | loss_box_reg_step:  0.14762 | loss_mask_step:  0.17398 | loss_objectness_step:  0.16549 | loss_rpn_box_reg_step:  0.15259 | loss_classifier_epoch:  0.09108 | loss_box_reg_epoch:  0.17290 | loss_mask_epoch:  0.18198 | loss_objectness_epoch:  0.10446 | loss_rpn_box_reg_epoch:  0.14192
# [0010] loss:  0.72500 | loss_classifier_step:  0.13895 | loss_box_reg_step:  0.30936 | loss_mask_step:  0.23595 | loss_objectness_step:  0.08490 | loss_rpn_box_reg_step:  0.10567 | loss_classifier_epoch:  0.09655 | loss_box_reg_epoch:  0.17307 | loss_mask_epoch:  0.18246 | loss_objectness_epoch:  0.11114 | loss_rpn_box_reg_epoch:  0.16797
# [0011] loss:  0.66600 | loss_classifier_step:  0.07671 | loss_box_reg_step:  0.16090 | loss_mask_step:  0.18912 | loss_objectness_step:  0.11459 | loss_rpn_box_reg_step:  0.19005 | loss_classifier_epoch:  0.09034 | loss_box_reg_epoch:  0.16646 | loss_mask_epoch:  0.17613 | loss_objectness_epoch:  0.10264 | loss_rpn_box_reg_epoch:  0.14597
# [0012] loss:  0.75700 | loss_classifier_step:  0.05412 | loss_box_reg_step:  0.19997 | loss_mask_step:  0.26257 | loss_objectness_step:  0.16073 | loss_rpn_box_reg_step:  0.16498 | loss_classifier_epoch:  0.09899 | loss_box_reg_epoch:  0.18085 | loss_mask_epoch:  0.18293 | loss_objectness_epoch:  0.10601 | loss_rpn_box_reg_epoch:  0.15646
# [0013] loss:  0.74600 | loss_classifier_step:  0.03220 | loss_box_reg_step:  0.09799 | loss_mask_step:  0.12459 | loss_objectness_step:  0.18442 | loss_rpn_box_reg_step:  0.31026 | loss_classifier_epoch:  0.09092 | loss_box_reg_epoch:  0.16798 | loss_mask_epoch:  0.17693 | loss_objectness_epoch:  0.10895 | loss_rpn_box_reg_epoch:  0.16306
# [0014] loss:  0.72200 | loss_classifier_step:  0.09108 | loss_box_reg_step:  0.16591 | loss_mask_step:  0.17423 | loss_objectness_step:  0.08865 | loss_rpn_box_reg_step:  0.10555 | loss_classifier_epoch:  0.09291 | loss_box_reg_epoch:  0.17519 | loss_mask_epoch:  0.18317 | loss_objectness_epoch:  0.10575 | loss_rpn_box_reg_epoch:  0.16057
# [0015] loss:  0.67500 | loss_classifier_step:  0.06559 | loss_box_reg_step:  0.21462 | loss_mask_step:  0.26298 | loss_objectness_step:  0.11317 | loss_rpn_box_reg_step:  0.16270 | loss_classifier_epoch:  0.08958 | loss_box_reg_epoch:  0.16675 | loss_mask_epoch:  0.17750 | loss_objectness_epoch:  0.10975 | loss_rpn_box_reg_epoch:  0.15209
# [0016] loss:  0.68200 | loss_classifier_step:  0.11691 | loss_box_reg_step:  0.15780 | loss_mask_step:  0.14281 | loss_objectness_step:  0.05375 | loss_rpn_box_reg_step:  0.12797 | loss_classifier_epoch:  0.09070 | loss_box_reg_epoch:  0.17733 | loss_mask_epoch:  0.18189 | loss_objectness_epoch:  0.10825 | loss_rpn_box_reg_epoch:  0.15582
# [0017] loss:  0.70900 | loss_classifier_step:  0.04385 | loss_box_reg_step:  0.13322 | loss_mask_step:  0.16969 | loss_objectness_step:  0.17633 | loss_rpn_box_reg_step:  0.13749 | loss_classifier_epoch:  0.09422 | loss_box_reg_epoch:  0.17533 | loss_mask_epoch:  0.18155 | loss_objectness_epoch:  0.11044 | loss_rpn_box_reg_epoch:  0.15130
# [0018] loss:  0.67200 | loss_classifier_step:  0.06725 | loss_box_reg_step:  0.15419 | loss_mask_step:  0.14985 | loss_objectness_step:  0.25654 | loss_rpn_box_reg_step:  0.26088 | loss_classifier_epoch:  0.09571 | loss_box_reg_epoch:  0.17463 | loss_mask_epoch:  0.18156 | loss_objectness_epoch:  0.10155 | loss_rpn_box_reg_epoch:  0.14860
# [0019] loss:  0.75800 | loss_classifier_step:  0.15973 | loss_box_reg_step:  0.30189 | loss_mask_step:  0.27057 | loss_objectness_step:  0.05392 | loss_rpn_box_reg_step:  0.22462 | loss_classifier_epoch:  0.09533 | loss_box_reg_epoch:  0.17717 | loss_mask_epoch:  0.18561 | loss_objectness_epoch:  0.10546 | loss_rpn_box_reg_epoch:  0.15693

# %% [markdown]
# ***
# **Inference**

# %%
full_model = detector.FullDetector([basemodel], [PATCHSIZE], slacks=[128])
#or load saved model
#import pickle
#full_model = pickle.load(open('model.pkl','rb'))

# %%
VALIDATION_IMAGE = 'data/conifer/val/ODPS017-2.1.jpg'

image   = full_model.load_image(VALIDATION_IMAGE)
output  = full_model.process_image(image, progress_callback=lambda x:print(f'Progress: {x*100:.1f}%', end='\r'))

figure(0, (16,10))
subplot(211);
imshow( image ); axis('off');
subplot(212);
imshow( output.squeeze() ); axis('off');
# Out:
# Progress: 100.0%

# %% [markdown]
# ***

# %%
#optionally save the model
#import pickle
#open('model.pkl','wb').write( pickle.dumps(full_model) )
