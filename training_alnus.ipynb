# %%
import sys, os
#restrict gpu usage
os.environ["CUDA_VISIBLE_DEVICES"]="0"

import torch, torchvision
print('PyTorch version:          ', torch.__version__)
import pytorch_lightning as pl
print('PyTorch Lightning version:', pl.__version__)

import glob, tempfile
from pylab import *
import dataset, detector, util, evaluation

import PIL
PIL.Image.MAX_IMAGE_PIXELS = None #Needed to open large images

import warnings
warnings.simplefilter("ignore")
# Out:
# PyTorch version:           1.6.0+cu101
# PyTorch Lightning version: 1.0.6

# %% [markdown]
# ***
# **Data collection**

# %%
IMAGEFILES    = sorted(glob.glob('data/alnus/train/*.jpg', recursive=True))
LABELFILES    = sorted(glob.glob('data/alnus/train/*.png', recursive=True))

print(f'Found {len(IMAGEFILES)} images and {len(LABELFILES)} annotations')
assert len(IMAGEFILES) == len(LABELFILES)
# Out:
# Found 89 images and 89 annotations

# %%
#example images
PATCHSIZE = 1000
ds = dataset.Dataset(IMAGEFILES, LABELFILES, patchsize=PATCHSIZE, augment=True)

figure(0, (20,8))
for i in range(5):
    j     = np.random.randint(len(ds))
    a0,b0 = ds[j]
    subplot(2,5,i+1);   imshow(a0.transpose(1,2,0)); axis('off'); 
    [util.draw_box(b.numpy(), color='k', linewidth=2) for b in b0['boxes'] ];
    if len(b0['masks']):
        subplot(2,5,i+1+5); imshow(b0['masks'].max(0)[0].numpy()); axis('off');

# %% [markdown]
# ***
# **Training**

# %%
basemodel = detector.create_conifer_basemodel()
trainer   = detector.create_trainer(epochs=20)
loader    = dataset.create_dataloader(ds, shuffle=True, batchsize=1)
trainer.fit(detector.TrainingModel(basemodel), loader)
basemodel.cpu().eval();
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | basemodel | MaskRCNN | 44 M
# [0000] loss:  0.56000 | loss_classifier_step:  0.08013 | loss_box_reg_step:  0.12380 | loss_mask_step:  0.11102 | loss_objectness_step:  0.00419 | loss_rpn_box_reg_step:  0.01949 | loss_classifier_epoch:  0.36761 | loss_box_reg_epoch:  0.26343 | loss_mask_epoch:  0.19081 | loss_objectness_epoch:  0.25209 | loss_rpn_box_reg_epoch:  0.07426
# [0001] loss:  0.43100 | loss_classifier_step:  0.17316 | loss_box_reg_step:  0.18890 | loss_mask_step:  0.13024 | loss_objectness_step:  0.04199 | loss_rpn_box_reg_step:  0.02914 | loss_classifier_epoch:  0.11692 | loss_box_reg_epoch:  0.15755 | loss_mask_epoch:  0.11314 | loss_objectness_epoch:  0.04722 | loss_rpn_box_reg_epoch:  0.05226
# [0002] loss:  0.45700 | loss_classifier_step:  0.08799 | loss_box_reg_step:  0.12181 | loss_mask_step:  0.10741 | loss_objectness_step:  0.09830 | loss_rpn_box_reg_step:  0.03181 | loss_classifier_epoch:  0.10800 | loss_box_reg_epoch:  0.13656 | loss_mask_epoch:  0.10371 | loss_objectness_epoch:  0.05141 | loss_rpn_box_reg_epoch:  0.04590
# [0003] loss:  0.40300 | loss_classifier_step:  0.07153 | loss_box_reg_step:  0.12010 | loss_mask_step:  0.10159 | loss_objectness_step:  0.00448 | loss_rpn_box_reg_step:  0.02776 | loss_classifier_epoch:  0.10122 | loss_box_reg_epoch:  0.12317 | loss_mask_epoch:  0.10038 | loss_objectness_epoch:  0.03589 | loss_rpn_box_reg_epoch:  0.03948
# [0004] loss:  0.41200 | loss_classifier_step:  0.04509 | loss_box_reg_step:  0.10399 | loss_mask_step:  0.09063 | loss_objectness_step:  0.00296 | loss_rpn_box_reg_step:  0.00339 | loss_classifier_epoch:  0.09887 | loss_box_reg_epoch:  0.11215 | loss_mask_epoch:  0.09826 | loss_objectness_epoch:  0.03056 | loss_rpn_box_reg_epoch:  0.03887
# [0005] loss:  0.34100 | loss_classifier_step:  0.16110 | loss_box_reg_step:  0.18629 | loss_mask_step:  0.17673 | loss_objectness_step:  0.02153 | loss_rpn_box_reg_step:  0.01369 | loss_classifier_epoch:  0.09766 | loss_box_reg_epoch:  0.11947 | loss_mask_epoch:  0.09906 | loss_objectness_epoch:  0.03837 | loss_rpn_box_reg_epoch:  0.03840
# [0006] loss:  0.33600 | loss_classifier_step:  0.20498 | loss_box_reg_step:  0.23574 | loss_mask_step:  0.16171 | loss_objectness_step:  0.04590 | loss_rpn_box_reg_step:  0.03640 | loss_classifier_epoch:  0.09380 | loss_box_reg_epoch:  0.11188 | loss_mask_epoch:  0.09837 | loss_objectness_epoch:  0.03080 | loss_rpn_box_reg_epoch:  0.03919
# [0007] loss:  0.39100 | loss_classifier_step:  0.09826 | loss_box_reg_step:  0.12725 | loss_mask_step:  0.09058 | loss_objectness_step:  0.00925 | loss_rpn_box_reg_step:  0.01586 | loss_classifier_epoch:  0.09336 | loss_box_reg_epoch:  0.11333 | loss_mask_epoch:  0.09907 | loss_objectness_epoch:  0.02802 | loss_rpn_box_reg_epoch:  0.03960
# [0008] loss:  0.34600 | loss_classifier_step:  0.17557 | loss_box_reg_step:  0.15237 | loss_mask_step:  0.09795 | loss_objectness_step:  0.04343 | loss_rpn_box_reg_step:  0.04882 | loss_classifier_epoch:  0.09334 | loss_box_reg_epoch:  0.10965 | loss_mask_epoch:  0.09628 | loss_objectness_epoch:  0.03665 | loss_rpn_box_reg_epoch:  0.03715
# [0009] loss:  0.36300 | loss_classifier_step:  0.08553 | loss_box_reg_step:  0.14475 | loss_mask_step:  0.11623 | loss_objectness_step:  0.00637 | loss_rpn_box_reg_step:  0.05612 | loss_classifier_epoch:  0.09589 | loss_box_reg_epoch:  0.11723 | loss_mask_epoch:  0.10149 | loss_objectness_epoch:  0.05103 | loss_rpn_box_reg_epoch:  0.03877
# [0010] loss:  0.37900 | loss_classifier_step:  0.24419 | loss_box_reg_step:  0.17613 | loss_mask_step:  0.11993 | loss_objectness_step:  0.06484 | loss_rpn_box_reg_step:  0.05213 | loss_classifier_epoch:  0.09818 | loss_box_reg_epoch:  0.11532 | loss_mask_epoch:  0.10021 | loss_objectness_epoch:  0.04382 | loss_rpn_box_reg_epoch:  0.03913
# [0011] loss:  0.35500 | loss_classifier_step:  0.15794 | loss_box_reg_step:  0.22150 | loss_mask_step:  0.11437 | loss_objectness_step:  0.07886 | loss_rpn_box_reg_step:  0.05396 | loss_classifier_epoch:  0.09378 | loss_box_reg_epoch:  0.11462 | loss_mask_epoch:  0.09933 | loss_objectness_epoch:  0.02918 | loss_rpn_box_reg_epoch:  0.03629
# [0012] loss:  0.40300 | loss_classifier_step:  0.09051 | loss_box_reg_step:  0.11344 | loss_mask_step:  0.10400 | loss_objectness_step:  0.00806 | loss_rpn_box_reg_step:  0.01866 | loss_classifier_epoch:  0.09561 | loss_box_reg_epoch:  0.11333 | loss_mask_epoch:  0.09908 | loss_objectness_epoch:  0.02378 | loss_rpn_box_reg_epoch:  0.03722
# [0013] loss:  0.33000 | loss_classifier_step:  0.06172 | loss_box_reg_step:  0.09487 | loss_mask_step:  0.10619 | loss_objectness_step:  0.02529 | loss_rpn_box_reg_step:  0.01481 | loss_classifier_epoch:  0.09689 | loss_box_reg_epoch:  0.11287 | loss_mask_epoch:  0.09814 | loss_objectness_epoch:  0.04897 | loss_rpn_box_reg_epoch:  0.03699
# [0014] loss:  0.38000 | loss_classifier_step:  0.08399 | loss_box_reg_step:  0.14915 | loss_mask_step:  0.13629 | loss_objectness_step:  0.00458 | loss_rpn_box_reg_step:  0.02850 | loss_classifier_epoch:  0.09626 | loss_box_reg_epoch:  0.11443 | loss_mask_epoch:  0.09898 | loss_objectness_epoch:  0.02985 | loss_rpn_box_reg_epoch:  0.03787
# [0015] loss:  0.45900 | loss_classifier_step:  0.09041 | loss_box_reg_step:  0.12488 | loss_mask_step:  0.09432 | loss_objectness_step:  0.02174 | loss_rpn_box_reg_step:  0.06531 | loss_classifier_epoch:  0.09874 | loss_box_reg_epoch:  0.11407 | loss_mask_epoch:  0.09805 | loss_objectness_epoch:  0.03674 | loss_rpn_box_reg_epoch:  0.03820
# [0016] loss:  0.52400 | loss_classifier_step:  0.06342 | loss_box_reg_step:  0.12056 | loss_mask_step:  0.11716 | loss_objectness_step:  0.03695 | loss_rpn_box_reg_step:  0.02525 | loss_classifier_epoch:  0.09412 | loss_box_reg_epoch:  0.11657 | loss_mask_epoch:  0.09931 | loss_objectness_epoch:  0.05227 | loss_rpn_box_reg_epoch:  0.03701
# [0017] loss:  0.38900 | loss_classifier_step:  0.04338 | loss_box_reg_step:  0.06009 | loss_mask_step:  0.07405 | loss_objectness_step:  0.01248 | loss_rpn_box_reg_step:  0.00294 | loss_classifier_epoch:  0.09455 | loss_box_reg_epoch:  0.11141 | loss_mask_epoch:  0.09772 | loss_objectness_epoch:  0.02631 | loss_rpn_box_reg_epoch:  0.03745
# [0018] loss:  0.37500 | loss_classifier_step:  0.21639 | loss_box_reg_step:  0.25894 | loss_mask_step:  0.18505 | loss_objectness_step:  0.01645 | loss_rpn_box_reg_step:  0.11490 | loss_classifier_epoch:  0.09581 | loss_box_reg_epoch:  0.11613 | loss_mask_epoch:  0.09917 | loss_objectness_epoch:  0.04014 | loss_rpn_box_reg_epoch:  0.03769
# [0019] loss:  0.32900 | loss_classifier_step:  0.09603 | loss_box_reg_step:  0.09109 | loss_mask_step:  0.08658 | loss_objectness_step:  0.04082 | loss_rpn_box_reg_step:  0.01480 | loss_classifier_epoch:  0.09379 | loss_box_reg_epoch:  0.10807 | loss_mask_epoch:  0.09672 | loss_objectness_epoch:  0.04608 | loss_rpn_box_reg_epoch:  0.03692

# %% [markdown]
# ***
# **Inference**

# %%
full_model = detector.FullDetector([basemodel], [PATCHSIZE], slacks=[128])
#or load saved model
#import pickle
#full_model = pickle.load(open('model.pkl','rb'))

# %%
VALIDATION_IMAGE = 'data/alnus/val/AWAG02a-1-Final3.jpg'

image   = full_model.load_image(VALIDATION_IMAGE)
output  = full_model.process_image(image, progress_callback=lambda x:print(f'Progress: {x*100:.1f}%', end='\r'))

figure(0, (16,10))
subplot(121);
imshow( image ); axis('off');
subplot(122);
imshow( output.squeeze() ); axis('off');
# Out:
# Progress: 100.0%

# %% [markdown]
# ***

# %%
#optionally save the model
#import pickle
#open('model.pkl','wb').write( pickle.dumps(full_model) )
